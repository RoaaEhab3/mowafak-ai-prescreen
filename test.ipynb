# %%
from src.cv_parser import parse_cv
from src.agents.question_generator import generate_questions

# %%
import os
from dotenv import load_dotenv

load_dotenv()

print(os.getenv("GOOGLE_API_MODEL"))
# Out:
# gemini-2.5-flash

# %%
cv=parse_cv("D:\\Data Science\\Sprints\\grad\\mowafak-ai-prescreen\\mowafak-ai-prescreen\\old Roaa Ehab.pdf","1")
# Out:
# 2026-07-13T18:38:23.447018Z [info     ] cv_parse.start                 candidate_id=1 file_ext=.pdf
# 2026-07-13T18:38:34.956090Z [info     ] cv_parse.success               candidate_id=1 skills_count=26

# %%
print(generate_questions(cv, n_questions=3))
# Out:
# 2026-07-13T18:38:47.477989Z [info     ] question_gen.start             candidate_id=1 n=3
# 2026-07-13T18:38:55.686307Z [info     ] question_gen.success           candidate_id=1 count=3
# ...
